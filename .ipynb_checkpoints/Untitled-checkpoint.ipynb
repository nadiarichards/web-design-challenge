# %%
import pandas as pd

# %%
cities_df= pd.read_csv("Resources/cities.csv")

# %%
cities_df.sample(10)
# Out:
#      City_ID            City  Cloudiness Country        Date  Humidity    Lat  \
# 288      288          maceio          75      BR  1528905600        88  -9.67
# 391      391       maldonado          75      UY  1528902000        76 -34.91
# 131      131          majene          32      ID  1528905382       100  -3.54
# 146      146         waipawa          92      NZ  1528905390        94 -39.94
# 216      216  sainte-suzanne          76      CH  1528903800        48  47.51
# 219      219       kavaratti          80      IN  1528905424       100  10.57
# 426      426       bealanana          20      MG  1528905541        53 -14.54
# 14        14         chapais          40      CA  1528902000        38  49.78
# 257      257   makakilo city           1      US  1528901820        83  21.35
# 63        63          beloha           0      MG  1528905340        57 -25.17
#
#         Lng  Max Temp  Wind Speed
# 288  -35.74     75.20        6.93
# 391  -54.96     51.80       19.46
# ...

# %%
cities_df.to_html
# Out:
# <bound method DataFrame.to_html of      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
# ...

# %%
cities_df.to_html(open('cities.html', 'w'))
